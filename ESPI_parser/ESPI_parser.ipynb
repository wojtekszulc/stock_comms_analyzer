# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
import numpy as np
from IPython.display import HTML, display
import re
from selenium.webdriver.common.keys import Keys
from datetime import datetime
import os

# %%
start_time = (datetime.now())

# %%
def parse_url(soup):
    contents = soup.find("div", {'class':'dane'})
    section_index = contents.find_all("table", {'class':'nDokument'})[0] # spis treści
    section_footer = contents.find_all("table", {'class':'nDokument'})[1] # stopka - informacje o firmie
    link_raport = section_index.find("a")['href']
    link_raport = link_raport[link_raport.find('#')+1:]
    start = contents.find('a',{'name':link_raport})
    content_table = start.parent.next_sibling.next_sibling
    contents_nTekst = content_table.find_all("tr", {'class':'nTekst'})
    total = [(el.text) for el in contents_nTekst]
    return ''.join(total)

# %%
def parse_url_and_save(soup):
    contents = soup.find("div", {'class':'dane'})
    return contents

# %%
path = './htmls'

files = []
# r=root, d=directories, f = files
for r, d, f in os.walk(path):
    for file in f:
        if '.html' in file:
            files.append(os.path.join(r, file))
files.sort()

espi_info=[]
espi_bledy=[]
korupc=0
bledy=0
#espi = []
#espi.append(files[0])
#for f in files:
#files = files[0:1000]
for f in files:
    url = str(f)
    #print(url)
    try:
        soup = BeautifulSoup(open(f), "html.parser")
        soup_text = parse_url(soup).lower()
        espi_info.append(soup_text)
        if soup_text.find("getback")>0:
            print(soup_text[soup_text.find("getback")-50:soup_text.find("getback")+200])
            korupc+=1
    except:
        #print("Błąd przy numerze: "+str(f))
        espi_bledy.append(f)
        bledy+=1


print(len(files))
print(bledy)
print(bledy/len(files))
#print(espi_bledy)
print(korupc)
# Out:
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  przedterminowy wykup obligacji serii g
#
#
#
#  podstawa prawna
#
#
#
#
#
#
#
#
#
#
#  art. 17 ust. 1 mar - informacje poufne.
#
#
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  przedterminowy wykup obligacji serii h
#
#
#
#  podstawa prawna
#
#
#
#
#
#
#
#
#
#
#  art. 17 ust. 1 mar - informacje poufne.
#
#
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  zmiana terminu publikacji skonsolidowanego raportu kwartalnego za i kwartał 2019 roku
#                            zawierającego skrócone jednostkowe spr
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  zawarcie umowy określającej zasady współpracy z saturn tfi  s.a.
#
#
#
#  podstawa prawna
#
#
#
#
#
#
#
#
#
#
#  art. 17 ust. 1 mar - informacje poufne.
#
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  posiedzenie sądu rejonowego we wrocławiu w sprawie postępowania restrukturyzacyjnego
#                            prowadzonego w sprawie getback s.a. w r
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  zatwierdzenie układu getback s.a. w restrukturyzacji
#
#
#
#  podstawa prawna
#
#
#
#
#
#
#
#
#
#
#  art. 17 ust. 1 mar - informacje poufne.
#
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  czynności podejmowane przez getback s.a. w restrukturyzacji w ramach przeglądu opcji
#                            strategicznych
#
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  wysokość odzysków w miesiącu kwietniu 2019 r
#
#
#
#  podstawa prawna
#
#
#
#
#
#
#
#
#
#
#  art. 17 ust. 1 mar - informacje poufne.
#
#               ltd z siedzibą na malcie_nabywca_ a getback recovery s.r.l. z siedzibą w bukareszcie.
#                            przedmiotem umowy jest nabycie portfela niezabezpieczonych wierzytelności za cenę
#                            41,2 mln ron _
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  sprzedaż portfeli wierzytelności do spółki investcapital ltd _z grupy kapitałowej
#                            kruk_
#
#
#
#
#  pods
# pital tfi s.a., private equity managers s.a. oraz getback s.a.
#                            w restrukturyzacji.
#
#
#
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  powołanie pana tomasza strama w skład zarządu getback s.a. w restrukturyzacji jako
#                            wiceprezesa zarządu getback s.a. w restru
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  wysokość odzysków w maju 2019 r
#
#
#
#  podstawa prawna
#
#
#
#
#
#
#
#
#
#
#  art. 17 ust. 1 mar - informacje poufne.
#
#
# 009-2013_. pełnił również funkcję prezesa zarządu getback s.a.
#                            _2012-2013_, a w latach 2014-2017 był związany z kancelarią prawną "lexus" jako dyrektor
#                            zarządzający i lexus finance s.a. jako preze
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  korekta oczywistej omyłki pisarskiej w raporcie bieżącym espi 55/2019 z dnia 14 czerwca
#                            2019
#
#
#
#
#
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  opóźniona informacja poufna - ustanowienie zabezpieczenia oraz zawarcie i wykonanie
#                            porozumienia z globus sp. z o.o.
#
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  doręczenie do getback s.a. w restrukturyzacji pozwu globus sp. z o.o.
#
#
#
#  podstawa prawna
#
#
#
#
#
#
#
#
#
#
#  art. 17 ust. 1 mar - informa
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  korekta oczywistej pomyłki pisarskiej w raporcie bieżącym espi 58/2019 z dnia 28 czerwca
#                            2019 r.
#
#
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  wysokość odzysków w czerwcu 2019 r.
#
#
#
#  podstawa prawna
#
#
#
#
#
#
#
#
#
#
#  art. 17 ust. 1 mar - informacje poufne.
#
#
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  wysokość odzysków w lipcu 2019 r.
#
#
#
#  podstawa prawna
#
#
#
#
#
#
#
#
#
#
#  art. 17 ust. 1 mar - informacje poufne.
#
#
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  zmiana daty publikacji raportu rocznego getback s.a. w restrukturyzacji i skonsolidowanego
#                            raportu rocznego grupy kapitałowe
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  zmiana terminu publikacji skonsolidowanego raportu kwartalnego za i kwartał 2019 roku
#                            zawierającego skrócone jednostkowe spr
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  przeszacowanie wartości portfeli wierzytelności znajdujących się w zarządzaniu getback
#                            s.a. w restrukturyzacji
#
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  powództwa lartiq towarzystwo funduszy inwestycyjnych s.a. przeciwko getback s.a. w
#                            restrukturyzacji o zapłatę
#
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  aktualizacja informacji w zakresie powództw lartiq towarzystwo funduszy inwestycyjnych
#                            s.a. przeciwko getback s.a. w restruk
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  zmiana terminu publikacji skonsolidowanego raportu półrocznego za i półrocze 2019
#                            roku zawierającego skrócone jednostkowe sp
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  zmiana terminu publikacji skonsolidowanego raportu kwartalnego za iii kwartał 2019
#                            roku zawierającego skrócone jednostkowe s
# stycyjnym zamkniętym
#                            i getback windykacji niestandaryzowanym sekurytyzacyjnym funduszem inwestycyjnym zamkniętym
#                            _obecnie grom windykacji niestandaryzowany sekurytyzacyjny fundusz inwestycyjny zam
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  aktualizacja informacji w zakresie powództw lartiq towarzystwo funduszy inwestycyjnych
#                            s.a. przeciwko getback s.a. w restruk
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  przejściowe zawieszenie raportowania odzysków przez getback s.a. w restrukturyzacji
#
#
#
#  podstawa prawna
#
#
#
#
#
#
#
#
#
#
#  art. 17 ust. 1 mar - info
# ię warunków umowy cesji wierzytelności zawartej z getback recovery s.r.l.
#
#
#
#  podstawa prawna
#
#
#
#
#
#
#
#
#
#
#  art. 17 ust. 1 mar - informacje poufne.
#
#
#
#
#
#  treść raportu:
#
#
#
#
#
#
#
#
#
#
#
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  spełnienie się warunków umowy cesji wierzytelności zawartej ze spółką investcapital
#                            ltd z grupy kapitałowej kruk
#
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  zawarcie przez getback s.a. w restrukturyzacji umowy o prowadzenie ewidencji obligacji
#                            getback s.a. w restrukturyzacji i zwi
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  powołanie członków rady nadzorczej getback s.a. w restrukturyzacji kolejnej kadencji
#                            – uzupełnienie raportu 111/2018 z dnia
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  złożenie pozwu przeciwko lartiq towarzystwo funduszy inwestycyjnych s.a._dawniej trigon
#                            towarzystwo funduszy inwestycyjnych
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#  rezygnacja pana marcina tokarka z pełnienia funkcji członka zarządu getback s.a. w
#                            restrukturyzacji
#
#
#
#
#  skrócona nazwa emitenta
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  getback s.a.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  temat
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  wyznaczenie pani magdaleny nawłoki do pełnienia obowiązków prezesa zarządu getback
#                            s.a. w restruktury
#
#
#  data przekazania:
#  2019-11-07
#
#
#
#
#
#
#
#  getback spółka akcyjna w restrukturyzacji
#
#
#
#
#
#  _pełna nazwa emitenta_
#
#
#
#
#
#  getback s.a.
#
#  finanse inne _fin_
#
#
#
#
#
#  _skrócona nazwa emitenta_
#
#  _sektor wg klasyfikacji gpw w warszawie_
#
# 11383
# 845
# 0.07423350610559606
# 38

# %%
end_time = (datetime.now())

# %%
diff_time = print(end_time-start_time)
# Out:
# 0:06:25.159456
